# %%
import numpy as np

# Assuming we have the baseball data in a list of lists
# Each inner list contains [height_inches, weight_pounds]
baseball = [[74, 180],
    [72, 215],
    [72, 210],
    [73, 188],
    [69, 176],
    [69, 209],
    [71, 200],
    [76, 231],
    [71, 180],
    [73, 188],
    [73, 180],
    [74, 185],
    [74, 160],
    [69, 180],
    [70, 185],
    [73, 189],
    [75, 185],
    [78, 219],
    [79, 230],
    [76, 205],
    [74, 230],
    [76, 195],
    [72, 180],
    [71, 192],
    [75, 225],
    [77, 203],
    [74, 195],
    [73, 182],
    [74, 188],
    [78, 200],
    [73, 180],
    [75, 200],
    [73, 200],
    [75, 245],
    [75, 240],
    [74, 215],
    [69, 185],
    [71, 175],
    [74, 199],
    [73, 200],
    [73, 215],
    [76, 200],
    [74, 205],
    [74, 206],
    [70, 186],
    [72, 188],
    [77, 220],
    [74, 210],
    [70, 195],
    [73, 200],
    [75, 200],
    [76, 212],
    [76, 224],
    [78, 210],
    [74, 205],
    [74, 220],
    [76, 195],
    [77, 200],
    [81, 260],
    [78, 228],
    [75, 270],
    [77, 200],
    [75, 210],
    [76, 190],
    [74, 220],
    [72, 180],
    [72, 205],
    [75, 210],
    [73, 220],
    [73, 211],
    [73, 200],
    [70, 180],
    [70, 190],
    [70, 170],
    [76, 230],
    [68, 155],
    [71, 185],
    [72, 185],
    [75, 200],
    [75, 225],
    [75, 225],
    [75, 220],
    [68, 160],
    [74, 205],
    [78, 235],
    [71, 250],
    [73, 210],
    [76, 190],
    [74, 160],
    [74, 200],
    [79, 205],
    [75, 222],
    [73, 195],
    [76, 205],
    [74, 220],
    [74, 220],
    [73, 170],
    [72, 185],
    [74, 195],
    [73, 220],
    [74, 230],
    [72, 180],
    [73, 220],
    [69, 180],
    [72, 180],
    [73, 170],
    [75, 210],
    [75, 215],
    [73, 200],
    [72, 213],
    [72, 180],
    [76, 192],
    [74, 235],
    [72, 185],
    [77, 235],
    [74, 210],
    [77, 222],
    [75, 210],
    [76, 230],
    [80, 220],
    [74, 180],
    [74, 190],
    [75, 200],
    [78, 210],
    [73, 194],
    [73, 180],
    [74, 190],
    [75, 240],
    [76, 200],
    [71, 198],
    [73, 200],
    [74, 195],
    [76, 210],
    [76, 220],
    [74, 190],
    [73, 210],
    [74, 225],
    [70, 180],
    [72, 185],
    [73, 170],
    [73, 185],
    [73, 185],
    [73, 180],
    [71, 178],
    [74, 175],
    [74, 200],
    [72, 204],
    [74, 211],
    [71, 190],
    [74, 210],
    [73, 190],
    [75, 190],
    [75, 185],
    [79, 290],
    [73, 175],
    [75, 185],
    [76, 200],
    [74, 220],
    [76, 170],
    [78, 220],
    [74, 190],
    [76, 220],
    [72, 205],
    [74, 200],
    [76, 250],
    [74, 225],
    [75, 215],
    [78, 210],
    [75, 215],
    [72, 195],
    [74, 200],
    [72, 194],
    [74, 220],
    [70, 180],
    [71, 180],
    [70, 170],
    [75, 195],
    [71, 180],
    [71, 170],
    [73, 206],
    [72, 205],
    [71, 200],
    [73, 225],
    [72, 201],
    [75, 225],
    [74, 233],
    [74, 180],
    [75, 225],
    [73, 180],
    [77, 220],
    [73, 180],
    [76, 237],
    [75, 215],
    [74, 190],
    [76, 235],
    [75, 190],
    [73, 180],
    [71, 165],
    [76, 195],
    [75, 200],
    [72, 190],
    [71, 190],
    [77, 185],
    [73, 185],
    [74, 205],
    [71, 190],
    [72, 205],
    [74, 206],
    [75, 220],
    [73, 208],
    [72, 170],
    [75, 195],
    [75, 210],
    [74, 190],
    [72, 211],
    [74, 230],
    [71, 170],
    [70, 185],
    [74, 185],
    [77, 241],
    [77, 225],
    [75, 210],
    [75, 175],
    [78, 230],
    [75, 200],
    [76, 215],
    [73, 198],
    [75, 226],
    [75, 278],
    [79, 215],
    [77, 230],
    [76, 240],
    [71, 184],
    [75, 219],
    [74, 170],
    [69, 218],
    [71, 190],
    [76, 225],
    [72, 220],
    [72, 176],
    [70, 190],
    [72, 197],
    [73, 204],
    [71, 167],
    [72, 180],
    [71, 195],
    [73, 220],
    [72, 215],
    [73, 185],
    [74, 190],
    [74, 205],
    [72, 205],
    [75, 200],
    [74, 210],
    [74, 215],
    [77, 200],
    [75, 205],
    [73, 211],
    [72, 190],
    [71, 208],
    [74, 200],
    [77, 210],
    [75, 232],
    [75, 230],
    [75, 210],
    [78, 220],
    [78, 210],
    [74, 202],
    [76, 212],
    [78, 225],
    [76, 170],
    [70, 190],
    [72, 200],
    [80, 237],
    [74, 220],
    [74, 170],
    [71, 193],
    [70, 190],
    [72, 150],
    [71, 220],
    [74, 200],
    [71, 190],
    [72, 185],
    [71, 185],
    [74, 200],
    [69, 172],
    [76, 220],
    [75, 225],
    [75, 190],
    [76, 195],
    [73, 219],
    [76, 190],
    [73, 197],
    [77, 200],
    [73, 195],
    [72, 210],
    [72, 177],
    [77, 220],
    [77, 235],
    [71, 180],
    [74, 195],
    [74, 195],
    [73, 190],
    [78, 230],
    [75, 190],
    [73, 200],
    [70, 190],
    [74, 190],
    [72, 200],
    [73, 200],
    [73, 184],
    [75, 200],
    [75, 180],
    [74, 219],
    [76, 187],
    [73, 200],
    [74, 220],
    [75, 205],
    [75, 190],
    [72, 170],
    [73, 160],
    [73, 215],
    [72, 175],
    [74, 205],
    [78, 200],
    [76, 214],
    [73, 200],
    [74, 190],
    [75, 180],
    [70, 205],
    [75, 220],
    [71, 190],
    [72, 215],
    [78, 235],
    [75, 191],
    [73, 200],
    [73, 181],
    [71, 200],
    [75, 210],
    [77, 240],
    [72, 185],
    [69, 165],
    [73, 190],
    [74, 185],
    [72, 175],
    [70, 155],
    [75, 210],
    [70, 170],
    [72, 175],
    [72, 220],
    [74, 210],
    [73, 205],
    [74, 200],
    [76, 205],
    [75, 195],
    [80, 240],
    [72, 150],
    [75, 200],
    [73, 215],
    [74, 202],
    [74, 200],
    [73, 190],
    [75, 205],
    [75, 190],
    [71, 160],
    [73, 215],
    [75, 185],
    [74, 200],
    [74, 190],
    [72, 210],
    [74, 185],
    [74, 220],
    [74, 190],
    [73, 202],
    [76, 205],
    [75, 220],
    [72, 175],
    [73, 160],
    [73, 190],
    [73, 200],
    [72, 229],
    [72, 206],
    [72, 220],
    [72, 180],
    [71, 195],
    [75, 175],
    [75, 188],
    [74, 230],
    [73, 190],
    [75, 200],
    [79, 190],
    [74, 219],
    [76, 235],
    [73, 180],
    [74, 180],
    [74, 180],
    [70, 200],
    [74, 195],
    [75, 220],
    [74, 230],
    [76, 170],
    [75, 220],
    [75, 230],
    [76, 165],
    [75, 205],
    [75, 192],
    [75, 210],
    [74, 205],
    [75, 200],
    [75, 210],
    [74, 180],
    [75, 190],
    [73, 196],
    [75, 180],
    [76, 230],
    [78, 180],
    [74, 205],
    [73, 250],
    [77, 200],
    [75, 225],
    [73, 175],
    [75, 220],
    [75, 170],
    [75, 190],
    [78, 245],
    [77, 240],
    [77, 215],
    [71, 250],
    [76, 220],
    [71, 224],
    [75, 210],
    [78, 195],
    [77, 200],
    [75, 220],
    [73, 205],
    [76, 200],
    [77, 250],
    [73, 200],
    [75, 220],
    [76, 192],
    [75, 185],
    [77, 185],
    [75, 195],
    [74, 202],
    [75, 200],
    [73, 194],
    [76, 220],
    [77, 180],
    [73, 200],
    [75, 225],
    [73, 206],
    [76, 235],
    [73, 305],
    [72, 190],
    [75, 190],
    [76, 220],
    [77, 220],
    [74, 170],
    [76, 185],
    [76, 190],
    [74, 210],
    [76, 185],
    [76, 195],
    [73, 184],
    [75, 200],
    [77, 210],
    [75, 193],
    [74, 225],
    [75, 200],
    [76, 200],
    [77, 210],
    [81, 260],
    [78, 228],
    [75, 270],
    [77, 200],
    [75, 210],
    [76, 190],
    [74, 220],
    [72, 180],
    [72, 205],
    [75, 210],
    [73, 220],
    [73, 211],
    [73, 200],
    [70, 180],
    [70, 190],
    [70, 170],
    [76, 230],
    [68, 155],
    [71, 185],
    [72, 185]]

# Giả sử chúng ta đã có dữ liệu baseball như trong phần trước

# 1. Tạo 2D numpy array từ np_baseball từ baseball
np_baseball = np.array(baseball)

# 2. In ra giá trị của dòng thứ 50 trong np_baseball
print("2. Giá trị của dòng thứ 50:")
print(np_baseball[49])

# 3. Tạo numpy array np_weight với dữ liệu được lấy từ cột hai của np_baseball
np_weight = np_baseball[:, 1]

# 4. Tìm chiều cao của vận động viên thứ 124
height_124 = np_baseball[123, 0]  # Chú ý: index bắt đầu từ 0
print(f"4. Chiều cao của vận động viên thứ 124: {height_124} inch")

# 5. Tính chiều cao trung bình và cân nặng trung bình của các cầu thủ
avg_height = np.mean(np_baseball[:, 0])
avg_weight = np.mean(np_baseball[:, 1])
print(f"5. Chiều cao trung bình: {avg_height:.2f} inch")
print(f"   Cân nặng trung bình: {avg_weight:.2f} pounds")

# 6. Phân tích mối tương quan giữa chiều cao và cân nặng
correlation = np.corrcoef(np_baseball[:, 0], np_baseball[:, 1])[0, 1]
print(f"6. Hệ số tương quan giữa chiều cao và cân nặng: {correlation:.4f}")

if correlation > 0.7:
    print("   Có tương quan mạnh giữa chiều cao và cân nặng.")
elif correlation > 0.5:
    print("   Có tương quan trung bình giữa chiều cao và cân nặng.")
elif correlation > 0.3:
    print("   Có tương quan yếu giữa chiều cao và cân nặng.")
else:
    print("   Hầu như không có tương quan giữa chiều cao và cân nặng.")
# Out:
# 2. Giá trị của dòng thứ 50:
# [ 73 200]
# 4. Chiều cao của vận động viên thứ 124: 78 inch
# 5. Chiều cao trung bình: 73.96 inch
#    Cân nặng trung bình: 201.79 pounds
# 6. Hệ số tương quan giữa chiều cao và cân nặng: 0.4620
#    Có tương quan yếu giữa chiều cao và cân nặng.
